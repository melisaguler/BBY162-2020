# %% [markdown]
# <a href="https://colab.research.google.com/github/melisaguler/BBY162-2020/blob/master/basit_katalog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Kütüphane Kataloguna hosgeldiniz")
KullaniciAdi = "MelisaGuler"
Sifre = "2618"
gAdi = input("Kullanıcı Adınızı Giriniz: ")
gSifre = input("Şifrenizi Giriniz: ")

dosya = open("kitap_listesi.txt", "w")
dosya.write("Lev Tolstoy-İnsan Ne İle Yaşar-2014-Bilge Kültür Sanat-1789548654886\nJohn Steinbeck-Gazap Üzümleri-2015-Sel Yayıncılık-8789547654589\nAnton Pavloviç Çehov-Altıncı Koğuş-2017-İş Bankası Kültür Yayınları-2789548954795\nCharles Dickens-İki Şehrin Hikayesi-2018-Can Yayınları-3189548654811\nHonore de Balzac-Vadideki Zambak-2019-Koridor Yayıncılık-7489548554791")
dosya.close()

#dosya = open("kitap_listesi.txt", "r")
#print(dosya.read())
#dosya.close()

if gAdi == KullaniciAdi and gSifre == Sifre:
    print("Hoş Geldiniz")
KATALOG = input("Yazar Adında Arama Yapmak İçin Y Tuşuna Basınız \n"
                "Eser Adında Arama Yapmak İçin E Tuşuna Basınız \n"
                "Basım Yılı Bilgisine Göre Arama Yapmak İçin B Tuşuna Basınız \n"
                "Yayın evi Arama Yapmak İçin N Tuşuna Basınız \n"
                "ISBN  Bilgisine Göre Arama Yapmak için I Tuşuna Basınız \n")
if KATALOG == "Y":
        kullanici = input("Bulmak İstediğiniz  Yazar Adını Yazınız: ").casefold() #yazar adını yazınız
        if kullanici == "Lev Tolstoy".casefold():
            print("Lev Tolstoy-İnsan Ne İle Yaşar-2014-Bilge Kültür Sanat-1789548654886")
        elif kullanici == "John Steinbeck".casefold():
            print("John Steinbeck-Gazap Üzümleri-2015-Sel Yayıncılık-8789547654589")
        elif kullanici == "Anton Pavloviç Çehov".casefold():
            print("Anton Pavloviç Çehov-Altıncı Koğuş-2017-İş Bankası Kültür Yayınları-2789548954795")
        elif kullanici == "Charles Dickens".casefold():
            print("Charles Dickens-İki Şehrin Hikayesi-2018-Can Yayınları-3189548654811")
        elif kullanici == "Honore de Balzac".casefold():
            print("Honore de Balzac-Vadideki Zambak-2019-Koridor Yayıncılık-7489548554791")
        else:
            print("Yazar Adı Kataloğumuzda Bulunmamaktadır...")
if KATALOG == "E":
        kullanici = input("Bulmak İstediğiniz Eserin Adını Yazınız: ").casefold() #Eser adı
        if kullanici == "İnsan Ne İle Yaşar".casefold():
            print("Lev Tolstoy-İnsan Ne İle Yaşar-2014-Bilge Kültür Sanat-1789548654886")
        elif kullanici =="Gazap Üzümleri".casefold():
            print("John Steinbeck-Gazap Üzümleri-2015-Sel Yayıncılık-8789547654589")
        elif kullanici == "Altıncı Koğuş".casefold():
            print("Anton Pavloviç Çehov-Altıncı Koğuş-2017-İş Bankası Kültür Yayınları-2789548954795")
        elif kullanici == "İki Şehrin Hikayesi".casefold():
            print("Charles Dickens-İki Şehrin Hikayesi-2018-Can Yayınları-3189548654811")
        elif kullanici == "Vadideki Zambak".casefold():
            print("Honore de Balzac-Vadideki Zambak-2019-Koridor Yayıncılık-7489548554791")
        else:
            print("Aradığınız Eser Kataloğumuzda Bulunmamaktadır...")
if KATALOG == "B":
        kullanici = input("Bulmak İstediğiniz Eserin Basım Yılını Yazınız: ") #Basım Yılı
        if kullanici == "2014":
            print("Lev Tolstoy-İnsan Ne İle Yaşar-2014-Bilge Kültür Sanat-1789548654886")
        elif kullanici == "2015":
            print("John Steinbeck-Gazap Üzümleri-2015-Sel Yayıncılık-8789547654589")
        elif kullanici == "2017":
            print("Anton Pavloviç Çehov-Altıncı Koğuş-2017-İş Bankası Kültür Yayınları-2789548954795")
        elif kullanici == "2018":
            print("Charles Dickens-İki Şehrin Hikayesi-2018-Can Yayınları-3189548654811")
        elif kullanici == "2019":
            print("Honore de Balzac-Vadideki Zambak-2019-Koridor Yayıncılık-7489548554791")
        else:
            print("Basım Yılı Bulunmamaktadır...")
if KATALOG == "N":
        kullanici = input("Bulmak İstediğiniz Eserin Yayın Evini Yazınız: ").casefold() #Yayınevi
        if kullanici =="Bilge Kültür Sanat".casefold():
            print("Lev Tolstoy-İnsan Ne İle Yaşar-2014-Bilge Kültür Sanat-1789548654886")
        elif kullanici == "Sel Yayıncılık".casefold():
            print("John Steinbeck-Gazap Üzümleri-2015-Sel Yayıncılık-8789547654589")
        elif kullanici == "İş Bankası Kültür Yayınları".casefold():
            print("Anton Pavloviç Çehov-Altıncı Koğuş-2017-İş Bankası Kültür Yayınları-2789548954795")
        elif kullanici == "Can Yayınları".casefold():
            print("Charles Dickens-İki Şehrin Hikayesi-2018-Can Yayınları-3189548654811")
        elif kullanici == "Koridor Yayıncılık".casefold():
            print("Honore de Balzac-Vadideki Zambak-2019-Koridor Yayıncılık-7489548554791")
        else:
            print("Yayınevi Kataloğumuzda  Bulunmamaktadır.")
if KATALOG == "I":
          kullanici = input("Bulmak İstediğiniz Eserin ISBN numarasını Yazınız: ").casefold() #ISBN Numarası
          if kullanici =="1789548654886".casefold():
            print("Lev Tolstoy-İnsan Ne İle Yaşar-2014-Bilge Kültür Sanat-1789548654886")
          elif kullanici =="8789547654589".casefold():
            print("John Steinbeck-Gazap Üzümleri-2015-Sel Yayıncılık-8789547654589")
          elif kullanici =="2789548954795".casefold():
            print("Anton Pavloviç Çehov-Altıncı Koğuş-2017-İş Bankası Kültür Yayınları-2789548954795")
          elif kullanici =="3189548654811".casefold():
            print("Charles Dickens-İki Şehrin Hikayesi-2018-Can Yayınları-3189548654811")
          elif kullanici =="7489548554791".casefold():
              print("Honore de Balzac-Vadideki Zambak-2019-Koridor Yayıncılık-7489548554791")
          else:
            print("ISBN numarası Kataloğumuzda  Bulunamadı.")




kullanici = input("Yeni Eser Eklemek İster Misiniz?")
if kullanici == "Evet":
        yazaradı = input("yazaradı: ")
        eseradı = input("eseradı: ")
        basımyılı = input("basımyılı: ")
        yayınevi = input("yayınevi: ")
        ISBN = input("ISBN:")         
        dosya = open("kitap_listesi.txt", "a")

        dosya.write(yazaradı + " -- ")
        dosya.write(eseradı + " -- ")
        dosya.write(basımyılı + " -- ")
        dosya.write(yayınevi + " ")
        dosya.write(ISBN + " ")
        dosya.close()
elif kullanici == "Hayır":
        print("Programdan Çıkış Yapabilirsiniz.İyi günler")
else:
    print("Kullanıcı Adınızı veya Şifrenizi Yanlış Girdiniz.\nLütfen Tekrardan Deneyiniz...")
# Out:
# Kütüphane Kataloguna hosgeldiniz
